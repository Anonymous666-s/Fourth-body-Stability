# %% [markdown]
# # Three-body Problem Simulation
# #### This code is dedicated to simulate the motion of three bodies in free space

# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt

#Solutions List (initial conditions)
y01 = [-1     ,#x1
  0             ,#y1
  1            ,#x2
  0             ,#y2
  0               ,#x3
  0             ,#y3
  0.347111       ,#vx1
  0.532728       ,#vy1
  0.347111       ,#vx2
  0.532728       ,#vy2
  -2 * 0.347111  ,#vx3
  -2 * 0.532728   #vy3 
]

y02 = [-1     ,#x1
  0             ,#y1
  1            ,#x2
  0             ,#y2
  0               ,#x3
  0             ,#y3
  0.306893    ,#vx1
  0.125507       ,#vy1
  0.306893       ,#vx2
  0.125507       ,#vy2
  -2 * 0.306893  ,#vx3
  -2 * 0.125507   #vy3 
]

y03 = [-1     ,#x1
  0             ,#y1
  1            ,#x2
  0             ,#y2
  0               ,#x3
  0             ,#y3
  0.392955    ,#vx1
  0.097579       ,#vy1
  0.392955       ,#vx2
  0.097579       ,#vy2
  -2 * 0.392955  ,#vx3
  -2 * 0.097579   #vy3 
]

y04 = [-1     ,#x1
  0             ,#y1
  1            ,#x2
  0             ,#y2
  0               ,#x3
  0             ,#y3
  0.184279    ,#vx1
  0.587188       ,#vy1
  0.184279       ,#vx2
  0.587188       ,#vy2
  -2 * 0.184279  ,#vx3
  -2 * 0.587188   #vy3 
]

y05 = [-1     ,#x1
  0             ,#y1
  1            ,#x2
  0             ,#y2
  0               ,#x3
  0             ,#y3
  0.080584    ,#vx1
  0.588836       ,#vy1
  0.080584       ,#vx2
  0.588836       ,#vy2
  -2 * 0.080584  ,#vx3
  -2 * 0.588836   #vy3 
]

y06 = [-1     ,#x1
  0             ,#y1
  1            ,#x2
  0             ,#y2
  0               ,#x3
  0             ,#y3
  0.083300    ,#vx1
  0.127889       ,#vy1
  0.083300       ,#vx2
  0.127889       ,#vy2
  -2 * 0.083300  ,#vx3
  -2 * 0.127889   #vy3 
]

y07 = [-1     ,#x1
  0             ,#y1
  1            ,#x2
  0             ,#y2
  0               ,#x3
  0             ,#y3
  0.464445    ,#vx1
  0.396060       ,#vy1
  0.464445       ,#vx2
  0.396060       ,#vy2
  -2 * 0.464445  ,#vx3
  -2 * 0.396060   #vy3 
]

y08 = [-1     ,#x1
  0             ,#y1
  1            ,#x2
  0             ,#y2
  0               ,#x3
  0             ,#y3
  0.439166    ,#vx1
  0.452968       ,#vy1
  0.439166       ,#vx2
  0.452968       ,#vy2
  -2 * 0.439166  ,#vx3
  -2 * 0.452968   #vy3 
]

y09 = [-1     ,#x1
  0             ,#y1
  1            ,#x2
  0             ,#y2
  0               ,#x3
  0             ,#y3
  0.383444    ,#vx1
  0.377364       ,#vy1
  0.383444       ,#vx2
  0.377364       ,#vy2
  -2 * 0.383444  ,#vx3
  -2 * 0.377364   #vy3 
]

y10 = [-1     ,#x1
  0             ,#y1
  1            ,#x2
  0             ,#y2
  0               ,#x3
  0             ,#y3
  0.405916    ,#vx1
  0.230163       ,#vy1
  0.405916       ,#vx2
  0.230163       ,#vy2
  -2 * 0.405916  ,#vx3
  -2 * 0.230163   #vy3 
]

y11 = [-1     ,#x1
  0             ,#y1
  1            ,#x2
  0             ,#y2
  0               ,#x3
  0             ,#y3
  0.350112    ,#vx1
  0.079339       ,#vy1
  0.350112       ,#vx2
  0.079339       ,#vy2
  -2 * 0.350112  ,#vx3
  -2 * 0.079339   #vy3 
]

y12 = [-1     ,#x1
  0             ,#y1
  1            ,#x2
  0             ,#y2
  0               ,#x3
  0             ,#y3
  0.559064    ,#vx1
  0.349192       ,#vy1
  0.559064       ,#vx2
  0.349192       ,#vy2
  -2 * 0.559064  ,#vx3
  -2 * 0.349192   #vy3 
]

y13 = [-1     ,#x1
  0             ,#y1
  1            ,#x2
  0             ,#y2
  0               ,#x3
  0             ,#y3
  0.513938    ,#vx1
  0.304736       ,#vy1
  0.513938       ,#vx2
  0.304736       ,#vy2
  -2 * 0.513938  ,#vx3
  -2 * 0.304736   #vy3 
]

y14 = [-1     ,#x1
  0             ,#y1
  1            ,#x2
  0             ,#y2
  0               ,#x3
  0             ,#y3
  0.282699    ,#vx1
  0.327209       ,#vy1
  0.282699       ,#vx2
  0.327209       ,#vy2
  -2 * 0.282699  ,#vx3
  -2 * 0.327209   #vy3 
]

y15 = [-1     ,#x1
  0             ,#y1
  1            ,#x2
  0             ,#y2
  0               ,#x3
  0             ,#y3
  0.416822    ,#vx1
  0.330333       ,#vy1
  0.416822       ,#vx2
  0.330333       ,#vy2
  -2 * 0.416822  ,#vx3
  -2 * 0.330333   #vy3 
]

y16 = [-1     ,#x1
  0             ,#y1
  1            ,#x2
  0             ,#y2
  0               ,#x3
  0             ,#y3
  0.417343    ,#vx1
  0.313100       ,#vy1
  0.417343       ,#vx2
  0.313100       ,#vy2
  -2 * 0.417343  ,#vx3
  -2 * 0.313100   #vy3 
]

Solutions = [y01, y02, y03, y04, y05, y06, y07, y08, y09, y10, y11, y12, y13, y14, y15, y16]

inp = int(input("Choose a solution from 1 to 16: "))
y0 = Solutions[inp - 1]
    

# The masses of the 3 bodies
m1 = 1
m2 = 1
m3 = 1

# Time steps
N = 64000
T = 0.001 

#Definition of the Function 
def ThreeBody(t,y, m1, m2, m3):
   f = np.zeros(12)
            
  # The velocities of the three bodies
   f[0] = y[6]
   f[1] = y[7]
   f[2] = y[8]
   f[3] = y[9]
   f[4] = y[10]
   f[5] = y[11]

  # The x and y accelerations of each object respectively
   f[6] = -m2*(y[0]-y[2])/(((y[0]-y[2])**2+(y[1]-y[3])**2)**(3/2)) \
        - m3*(y[0]-y[4])/(((y[0]-y[4])**2+(y[1]-y[5])**2)**(3/2))
        
   f[7] = -m2*(y[1]-y[3])/(((y[0]-y[2])**2+(y[1]-y[3])**2)**(3/2)) \
        -m3*(y[1]-y[5])/(((y[0]-y[4])**2+(y[1]-y[5])**2)**(3/2))
                  
   f[8] = -m1*(y[2]-y[0])/(((y[2]-y[0])**2+(y[3]-y[1])**2)**(3/2)) \
        -m3*(y[2]-y[4])/(((y[2]-y[4])**2+(y[3]-y[5])**2)**(3/2))
        
   f[9] = -m1*(y[3]-y[1])/(((y[2]-y[0])**2+(y[3]-y[1])**2)**(3/2)) \
        -m3*(y[3]-y[5])/(((y[2]-y[4])**2+(y[3]-y[5])**2)**(3/2))
                  
   f[10]= -m1*(y[4]-y[0])/(((y[4]-y[0])**2+(y[5]-y[1])**2)**(3/2)) \
        -m2*(y[4]-y[2])/(((y[4]-y[2])**2+(y[5]-y[3])**2)**(3/2))
        
   f[11]= -m1*(y[5]-y[1])/(((y[4]-y[0])**2+(y[5]-y[1])**2)**(3/2)) \
        -m2*(y[5]-y[3])/(((y[4]-y[2])**2+(y[5]-y[3])**2)**(3/2))
        
   return f  


#Solving for the positions of all bodies
t = np.linspace(0,N*T,N)
solution = solve_ivp(ThreeBody,[0,670],y0,t_eval=t,rtol=1e-12, args = (m1, m2, m3))

# Defining lists to contain the angular momenta (L), total kinetic energy (KET), 
# total potential energy (PET), and the total energy of the system (Energy).
L1 = []
L2 = []
L3=  []
LT = []
KET = []
PET = []
Energy = []

# Calculating the angular momentum and Energy of the system
for i in range(N):
    # Calculating the angular momentum of the system
    L1.append((solution.y[0][i] * solution.y[7][i])-(solution.y[1][i] * solution.y[6][i]))
    L2.append((solution.y[2][i] * solution.y[9][i])-(solution.y[3][i] * solution.y[8][i]))
    L3.append((solution.y[4][i] * solution.y[11][i])-(solution.y[5][i] * solution.y[10][i]))
    LT.append(L1[i] + L2[i] + L3[i])
    
    # Calculating the kinetic energy of the system
    v1 = (solution.y[6][i])**2 + (solution.y[7][i])**2
    v2 = (solution.y[8][i])**2 + (solution.y[9][i])**2
    v3 = (solution.y[10][i])**2 + (solution.y[11][i])**2
    KET.append(0.5 * ( v1 +  v2 + v3))
    
    # Calculating the potenial energy of the system
    r12 = np.sqrt((solution.y[2][i] - solution.y[0][i])**2 + (solution.y[3][i] - solution.y[1][i])**2)
    r23 = np.sqrt((solution.y[2][i] - solution.y[4][i])**2 + (solution.y[3][i] - solution.y[5][i])**2)
    r13 = np.sqrt((solution.y[0][i] - solution.y[4][i])**2 + (solution.y[1][i] - solution.y[5][i])**2)
    PET.append((-1/r12) - (1/r23) - (1/r13))
    
    # Calculating the total energy of the system
    Energy.append(KET[i] + PET[i])

# Printing the mean energy and angular momentum of the system
print(np.mean(Energy))
print(np.mean(LT))

# Calculating the period of the solution
PeriodicTime = []
for i in range(N):
    e = 0.0003
    if solution.y[0][0] - e <= solution.y[0][i] <= solution.y[0][0] + e \
    and solution.y[1][0] - e <= solution.y[1][i] <= solution.y[1][0] + e:
        PeriodicTime.append(i)
print(PeriodicTime)


#Evolution of Position with respect to Time
plt.plot(solution.y[0],solution.y[1],'green', label = 'Body 1') #Positions body 1
plt.plot(solution.y[2],solution.y[3],'red', label = 'Body 2') #Positions body 2
plt.plot(solution.y[4],solution.y[5],'blue', label = 'Body 3')#Positions body 3
plt.legend(loc='upper right')
plt.ylabel("Position(y)")
plt.xlabel("Position(x)")
plt.savefig("yin-yang-2bOriginal")
plt.show()

# Plotting the angular momentum versus time
plt.plot(t,LT)
plt.savefig("MOMENTUMGRAPH")
plt.xlabel("Time")
plt.show()

# Plotting total energy versus time
plt.plot(t, Energy)
plt.ylabel("Total Energy")
plt.xlabel("Time")
plt.show()
# Out:
# Choose a solution from 1 to 16:  16
# -1.683885527226183
# 3.3236661164217427e-06
# [0]

# %%
solution.y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 solution.y
#
# NameError: name 'solution' is not defined

# %%
plt.plot(solution.y[0],solution.y[1],'black', label = 'Body 1') #Positions body 1
plt.plot(solution.y[2],solution.y[3],'b', label = 'Body 2') #Positions body 2
plt.plot(solution.y[4],solution.y[5],'-r', label = 'Body 3')#Positions body 3
plt.legend(loc='upper right')
plt.ylabel("Position(y)")
plt.xlabel("Position(x)")
plt.show()

# %%
plt.plot(t, solution.y[0],'black', label = 'Body 1') #Positions body 1
plt.plot(t, solution.y[2],'b', label = 'Body 2') #Positions body 2
plt.plot(t, solution.y[4],'-r', label = 'Body 3')#Positions body 3
plt.legend(loc='upper right')
plt.ylabel("Position(x)")
plt.xlabel("time")
plt.show()

# %%
plt.plot(t,solution.y[1],'black', label = 'Body 1') #Positions body 1
plt.plot(t,solution.y[3],'b', label = 'Body 2') #Positions body 2
plt.plot(t,solution.y[5],'-r', label = 'Body 3')#Positions body 3
plt.legend(loc='upper right')
plt.ylabel("Position(y)")
plt.xlabel("time")
plt.show()

# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt



# The masses of the 3 bodies
m1_values = np.arange(1, 0, -0.001)  # Vary m1 from 1 to 0 with steps of 0.001
m2 = 1
m3 = 1

# Lists to store the results
f_values = []

# Iterate over different m1 values
for m1 in m1_values:
    # Solve for the positions of all bodies
    t = np.linspace(0, 100, 100000)
    solution = solve_ivp(ThreeBody, [0, 100], y0, t_eval=t, rtol=1e-12, args=(m1, m2, m3))

    # Calculate the period of the solution
    PeriodicTime = []
    for i in range(len(solution.t)):
        e = 0.0003
        if (
        solution.y[0][0] - e <= solution.y[0][i] <= solution.y[0][0] + e
        and solution.y[1][0] - e <= solution.y[1][i] <= solution.y[1][0] + e):
            PeriodicTime.append(i)

    # Check if the solution is stable (you can adjust the condition based on your criteria)
    if len(PeriodicTime) > 100:  # Just an example condition, adjust as needed
        f = np.max(solution.y[2]) - np.min(solution.y[2])  # Calculate f
        f_values.append((m1, f))

# Find the step with the least value of f
min_f_step = min(f_values, key=lambda x: x[1])

# Print the result
print(f"The minimum value of f occurred at m1 = {min_f_step[0]} with f = {min_f_step[1]}")
